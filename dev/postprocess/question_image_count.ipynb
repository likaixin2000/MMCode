# %%
import os
import re
import json

from PIL import Image
from tqdm import tqdm

def load_problems(problems_root, return_dict=False):
    subdirs = [
        os.path.join(problems_root, d) for d in os.listdir(problems_root) 
            if os.path.isdir(os.path.join(problems_root, d))
    ]
    problems = []
    
    for subdir in tqdm(sorted(subdirs)):  # Maintain the same order
        data_json_path = os.path.join(subdir, 'data.json')
        images_folder = os.path.join(subdir, 'images')
        problem_id = os.path.basename(subdir)

        # Read data.json
        with open(data_json_path, 'r') as file:
            problem_data = json.load(file)

            # Load images from 'images' folder
            images = []
            image_files = sorted([f for f in os.listdir(images_folder) if f.endswith('.png')],
                                    key=lambda x: int(os.path.splitext(x)[0]))
            for img_file in image_files:
                img_path = os.path.join(images_folder, img_file)
                image = Image.open(img_path).convert("RGBA")
                new_image = Image.new("RGBA", image.size, "WHITE") # Create a white rgba background
                new_image.paste(image, (0, 0), image)
                new_image = new_image.convert('RGB')
                del image
                images.append(new_image)
            
            problems.append( 
                {
                    'problem_id': problem_id,
                    'problem': problem_data,
                    'images': images,
                }
            )
    
    if return_dict:
        return {p['problem_id']: p for p in problems}
    else:
        return problems

# %%
problems = load_problems('/home/kaixin/Desktop/mmcode/mmcode_dataset')
for problem in tqdm(problems):
    for img_id, image in enumerate(problem["images"]):
        image.save(f'images_with_bg/{problem["problem_id"]}_{img_id}.png')
# Out:
#  41%|████      | 1773/4334 [00:37<00:53, 47.80it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 problems = load_problems('/home/kaixin/Desktop/mmcode/mmcode_dataset')
#       2 for problem in tqdm(problems):
#       3     for img_id, image in enumerate(problem["images"]):
#
# Cell In[1], line 30, in load_problems(problems_root, return_dict)
#      28 for img_file in image_files:
#      29     img_path = os.path.join(images_folder, img_file)
# ---> 30     image = Image.open(img_path).convert("RGBA")
#      31     new_image = Image.new("RGBA", image.size, "WHITE") # Create a white rgba background
#      32     new_image.paste(image, (0, 0), image)
#
# File ~/anaconda3/envs/mmcode/lib/python3.11/site-packages/PIL/Image.py:911, in Image.convert(self, mode, matrix, dither, palette, colors)
#     863 def convert(
#     864     self, mode=None, matrix=None, dither=None, palette=Palette.WEB, colors=256
#     865 ):
#     866     """
#     867     Returns a converted copy of this image. For the "P" mode, this
#     868     method translates pixels through the palette.  If mode is
#    (...)
#     908     :returns: An :py:class:`~PIL.Image.Image` object.
#     909     """
# --> 911     self.load()
#     913     has_transparency = self.info.get("transparency") is not None
#     914     if not mode and self.mode == "P":
#     915         # determine default mode
#
# File ~/anaconda3/envs/mmcode/lib/python3.11/site-packages/PIL/ImageFile.py:269, in ImageFile.load(self)
#     266         raise OSError(msg)
#     268 b = b + s
# --> 269 n, err_code = decoder.decode(b)
#     270 if n < 0:
#     271     break
#
# KeyboardInterrupt:
